# %%
from pathlib import Path
from xmljson import badgerfish as bf
from xml.etree.ElementTree import fromstring
import cv2
from lxml import etree

import matplotlib.pyplot as plt

from imantics import Dataset

# %%
dataset = Dataset.from_xml(Path("data/xml_example"))
# Out:
# <class 'collections.OrderedDict'>
# <class 'list'>
# <class 'list'>
# <class 'list'>

# %%
for image in dataset.iter_images():
    draw = image.draw()
    plt.imshow(draw)
    plt.show()
    etree.tostring(image.export(style='voc'), pretty_print=True).decode('utf-8')

# %%
# Conversion to COCO
import json
with open('example.json', 'w') as outfile:
    json.dump(dataset.coco(), outfile)

# %%
for category in dataset.iter_categories():
    print(category.export())
# Out:
# {'categories': [{'id': 1, 'name': 'dog', 'supercategory': None, 'metadata': {}, 'color': '#71e028'}]}
# {'categories': [{'id': 1, 'name': 'person', 'supercategory': None, 'metadata': {}, 'color': '#62f8ae'}]}
# {'categories': [{'id': 2, 'name': 'bicycle', 'supercategory': None, 'metadata': {}, 'color': '#242c9a'}]}
