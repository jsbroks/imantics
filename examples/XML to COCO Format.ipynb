# %%
from pathlib import Path
from xmljson import badgerfish as bf
from xml.etree.ElementTree import fromstring
import cv2
from lxml import etree

import matplotlib.pyplot as plt

from imantics import Dataset

# %%
dataset = Dataset.from_xml(Path("data/xml_example"))
# Out:
# [OrderedDict([('name', OrderedDict([('$', 'person')])), ('pose', OrderedDict([('$', 'Rear')])), ('truncated', OrderedDict([('$', 0)])), ('difficult', OrderedDict([('$', 0)])), ('bndbox', OrderedDict([('xmin', OrderedDict([('$', 344)])), ('ymin', OrderedDict([('$', 106)])), ('xmax', OrderedDict([('$', 444)])), ('ymax', OrderedDict([('$', 298)]))]))]), OrderedDict([('name', OrderedDict([('$', 'person')])), ('pose', OrderedDict([('$', 'Frontal')])), ('truncated', OrderedDict([('$', 0)])), ('difficult', OrderedDict([('$', 0)])), ('bndbox', OrderedDict([('xmin', OrderedDict([('$', 148)])), ('ymin', OrderedDict([('$', 108)])), ('xmax', OrderedDict([('$', 213)])), ('ymax', OrderedDict([('$', 187)]))]))]), OrderedDict([('name', OrderedDict([('$', 'person')])), ('pose', OrderedDict([('$', 'Unspecified')])), ('truncated', OrderedDict([('$', 0)])), ('difficult', OrderedDict([('$', 0)])), ('bndbox', OrderedDict([('xmin', OrderedDict([('$', 89)])), ('ymin', OrderedDict([('$', 27)])), ('xmax', OrderedDict([('$', 149)])), ('ymax', OrderedDict([('$', 217)]))]))]), OrderedDict([('name', OrderedDict([('$', 'person')])), ('pose', OrderedDict([('$', 'Unspecified')])), ('truncated', OrderedDict([('$', 0)])), ('difficult', OrderedDict([('$', 0)])), ('bndbox', OrderedDict([('xmin', OrderedDict([('$', 75)])), ('ymin', OrderedDict([('$', 39)])), ('xmax', OrderedDict([('$', 147)])), ('ymax', OrderedDict([('$', 124)]))]))]), OrderedDict([('name', OrderedDict([('$', 'bicycle')])), ('pose', OrderedDict([('$', 'Unspecified')])), ('truncated', OrderedDict([('$', 0)])), ('difficult', OrderedDict([('$', 0)])), ('bndbox', OrderedDict([('xmin', OrderedDict([('$', 77)])), ('ymin', OrderedDict([('$', 121)])), ('xmax', OrderedDict([('$', 178)])), ('ymax', OrderedDict([('$', 316)]))]))])]

# %%
for image in dataset.iter_images():
    draw = image.draw()
    plt.imshow(draw)
    plt.show()
    etree.tostring(image.export(style='voc'), pretty_print=True).decode('utf-8')

# %%
# Conversion to COCO

with open('example.json', 'w') as outfile:
    json.dump(dataset.coco(), outfile)
