# %%
import imglang as il
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-63c6012dd96c> in <module>()
# ----> 1 import imglang as il
#
# ModuleNotFoundError: No module named 'imglang'
